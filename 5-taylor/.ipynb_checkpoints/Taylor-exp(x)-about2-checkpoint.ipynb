# %% [markdown]
# ## Iclicker question

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from math import factorial

# %%
import sympy as sp
sp.init_printing()
x = sp.Symbol("x")

# %%
f = sp.exp(x)

f
# Out:
#  x
# ℯ

# %%
def plot_sympy(my_f, my_pts, **kwargs):
    f_values = np.array([my_f.subs(x, pt) for pt in my_pts])
    plt.plot(pts, f_values, **kwargs)

    
def semilogy_sympy(my_f, my_pts, **kwargs):
    f_values = np.array([my_f.subs(x, pt) for pt in my_pts])
    plt.semilogy(pts, f_values, **kwargs)

# %%
n = 4
xo = 2

# %%
taylor = 0

for i in range(n):
    taylor += f.diff(x, i).subs(x, xo)/factorial(i) * (x-xo)**i

error =  f - taylor

# %%
pts = np.linspace(-1, 4, 100)
plot_sympy(taylor, pts, label="taylor n=3")
plot_sympy(f, pts, label="f")
plt.legend(loc="best")
plt.grid()
plt.xlabel('$x$')
plt.ylabel('function values')
# Out:
# Text(0,0.5,'function values')

# %%
semilogy_sympy(error, pts, label="error")
semilogy_sympy(x**2, pts, label="$x$")
semilogy_sympy(x**3, pts, label="$x^3$")
semilogy_sympy(x**4, pts, label="$x^4$")
semilogy_sympy(x**5, pts, label="$x^5$")
plt.legend(loc="best")
plt.grid()
plt.xlabel('$x$')
plt.ylabel('error')
plt.title('Error and bounds when n = 2')
# Out:
# Text(0.5,1,'Error and bounds when n = 2')

# %%
semilogy_sympy(error, pts, label="error")
semilogy_sympy((x-2), pts, label="$(x-2)$")
semilogy_sympy((x-2)**2, pts, label="$(x-2)**2$")
semilogy_sympy((x-2)**3, pts, label="$(x-2)**3$")
semilogy_sympy((x-2)**4, pts, label="$(x-2)**4$")
semilogy_sympy((x-2)**5, pts, label="$(x-2)**5$")
plt.legend(loc="best")
plt.grid()
plt.xlabel('$x$')
plt.ylabel('error')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py:2210: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-cb5976360ff5> in <module>()
#       1 semilogy_sympy(error, pts, label="error")
# ----> 2 plt.semilogy((x-2), pts, label="$(x-2)$")
#       3 semilogy((x-2)**2, pts, label="$(x-2)**2$")
#       4 semilogy_sympy((x-2)**3, pts, label="$(x-2)**3$")
#       5 semilogy_sympy((x-2)**4, pts, label="$(x-2)**4$")
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in semilogy(*args, **kwargs)
#    3397                       mplDeprecation)
#    3398     try:
# -> 3399         ret = ax.semilogy(*args, **kwargs)
#    3400     finally:
#    3401         ax._hold = washold
#
# ...

# %%
(x-2)**
