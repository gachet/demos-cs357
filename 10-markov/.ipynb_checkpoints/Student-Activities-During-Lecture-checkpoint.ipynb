# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
# %matplotlib inline
import graph

# %% [markdown]
# <img src="StudentLecture.png" alt="Sparse" style="width: 500px;"/>

# %% [markdown]
# After one time step...  ($x_1 \leftarrow A x_0$)

# %%
A  = np.array([
    [0.6,  0.4, 0.2, 0.3],
    [0.2, 0.5, 0.1, 0.2],
    [0.15, 0.1,  0.7, 0.0],
    [0.05, 0, 0  , 0.5]
])

# %%
graph.graph_matrix(A,['lecture', 'web', 'hw', 'text'])

# %%
x0 = np.array([0.8, 0.1, 0.0, 0.1])
x1=A@x0
print("x1 = ",x1)
# Out:
# x1 =  [ 0.55  0.23  0.13  0.09]

# %% [markdown]
# What about after five time steps?

# %%
x = np.array([0.8, 0.1, 0.0, 0.1])
#x = np.array([0, 0.2, 0.1, 0.7])
print(x)
for k in range(5):
    x=A@x
    print("x = ",x)
# Out:
# [ 0.8  0.1  0.   0.1]
# x =  [ 0.55  0.23  0.13  0.09]
# x =  [ 0.475   0.256   0.1965  0.0725]
# x =  [ 0.44845  0.25715  0.2344   0.06   ]
# x =  [ 0.43681    0.253705   0.2570625  0.0524225]
# x =  [ 0.43070725  0.25040525  0.27083575  0.04805175]

# %% [markdown]
# What happens in the long run?

# %%
x0 = np.array([0.8, 0.1, 0.0, 0.1])

x = x0.copy()
its = 40
allx = np.zeros((4,its))
allx[:,0] = x

print("x0 = ",x)

for k in range(1,its):
    x = A.dot(x)
    allx[:,k] = x
    
plt.plot(allx.T)

print("x = ",x)
# Out:
# x0 =  [ 0.8  0.1  0.   0.1]
# x =  [ 0.42168675  0.2439759   0.29216867  0.04216867]
